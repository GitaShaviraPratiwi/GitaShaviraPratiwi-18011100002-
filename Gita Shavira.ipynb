# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns
import matplotlib as plt
data = pd.read_csv("tugas gita.csv",delimiter=";")
cm = sns.light_palette("gold", as_cmap=True)
data.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_c20a6d26_ceb2_11e9_8635_54424970d42brow0_col0 {
#             background-color:  #ffd807;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow0_col1 {
#             background-color:  #fff7ca;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow0_col2 {
#             background-color:  #ffe559;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow0_col3 {
#             background-color:  #ffd807;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow1_col0 {
#             background-color:  #fffade;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow1_col1 {
#             background-color:  #fff6c7;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow1_col2 {
#             background-color:  #ffe65e;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow1_col3 {
#             background-color:  #ffe869;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow2_col0 {
#             background-color:  #fff1a7;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow2_col1 {
#             background-color:  #ffdb1b;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow2_col2 {
#             background-color:  #ffdf36;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow2_col3 {
#             background-color:  #ffea7c;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow3_col0 {
#             background-color:  #ffed8c;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow3_col1 {
#             background-color:  #fff3b0;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow3_col2 {
#             background-color:  #fff1a7;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow3_col3 {
#             background-color:  #ffea79;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow4_col0 {
#             background-color:  #ffe03a;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow4_col1 {
#             background-color:  #ffe142;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow4_col2 {
#             background-color:  #ffda13;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow4_col3 {
#             background-color:  #ffda13;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow5_col0 {
#             background-color:  #ffdb1b;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow5_col1 {
#             background-color:  #fff6c7;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow5_col2 {
#             background-color:  #ffe765;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow5_col3 {
#             background-color:  #fff8d3;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow6_col0 {
#             background-color:  #ffe765;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow6_col1 {
#             background-color:  #ffef98;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow6_col2 {
#             background-color:  #fff9da;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow6_col3 {
#             background-color:  #fff7ca;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow7_col0 {
#             background-color:  #ffee94;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow7_col1 {
#             background-color:  #ffe452;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow7_col2 {
#             background-color:  #fff2ab;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow7_col3 {
#             background-color:  #ffe970;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow8_col0 {
#             background-color:  #fff3b3;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow8_col1 {
#             background-color:  #ffe34d;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow8_col2 {
#             background-color:  #ffe142;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow8_col3 {
#             background-color:  #ffe34d;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow9_col0 {
#             background-color:  #ffd804;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow9_col1 {
#             background-color:  #ffef9c;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow9_col2 {
#             background-color:  #ffd807;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow9_col3 {
#             background-color:  #fff9da;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow10_col0 {
#             background-color:  #fff5c2;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow10_col1 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow10_col2 {
#             background-color:  #ffec84;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow10_col3 {
#             background-color:  #ffee94;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow11_col0 {
#             background-color:  #ffde2a;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow11_col1 {
#             background-color:  #fff6c7;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow11_col2 {
#             background-color:  #ffde2a;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow11_col3 {
#             background-color:  #fff5c2;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow12_col0 {
#             background-color:  #ffe456;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow12_col1 {
#             background-color:  #ffe559;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow12_col2 {
#             background-color:  #ffdd23;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow12_col3 {
#             background-color:  #ffec88;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow13_col0 {
#             background-color:  #ffe975;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow13_col1 {
#             background-color:  #ffdd23;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow13_col2 {
#             background-color:  #ffec88;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow13_col3 {
#             background-color:  #ffed8c;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow14_col0 {
#             background-color:  #fff9da;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow14_col1 {
#             background-color:  #fff09f;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow14_col2 {
#             background-color:  #ffee90;
#             color:  #000000;
#         }    #T_c20a6d26_ceb2_11e9_8635_54424970d42brow14_col3 {
#             background-color:  #fff5c2;

# %%
colum = data.columns.tolist()
for x in colum :
    ds = [x for x in data[x]]
    desc = data[x].describe()
    array = [x for x in desc]
    print("Detail kolom",x)
    print("rata-rata: ",array[1])
    print("Median: ",np.median(np.array(ds)))
    print("Modus: ",stats.mode(ds))
    print("Standard deviasi: ",np.std(ds))
    print("varian: ",stats.variation(ds))
    print("Skewness: ",stats.skew(ds))
    print("Quartil 1: ",array[4])
    print("Quartil 2: ",array[5])
    print("Quartil 3: ",array[6])
    sns.distplot(data[x])
    
    print("\n")
# Out:
# Detail kolom Data 1
# rata-rata:  31.028
# Median:  31.0
# Modus:  ModeResult(mode=array([10]), count=array([16]))
# Standard deviasi:  17.637097720430084
# varian:  0.5684252198153308
# Skewness:  0.04037865369912075
# Quartil 1:  15.75
# Quartil 2:  31.0
# Quartil 3:  47.0
#
#
# Detail kolom Data 2
# rata-rata:  29.77
# Median:  29.0
# Modus:  ModeResult(mode=array([31]), count=array([15]))
# Standard deviasi:  17.553492529978186
# varian:  0.5896369677520386
# Skewness:  0.08681623088885974
# Quartil 1:  14.0
# Quartil 2:  29.0
# Quartil 3:  45.0
#
#
# Detail kolom Data 3
# rata-rata:  30.194
# Median:  30.0
# Modus:  ModeResult(mode=array([7]), count=array([18]))
# Standard deviasi:  17.520740966066477
# varian:  0.5802722715130979
# Skewness:  -0.009515290333714116
# Quartil 1:  15.0
# Quartil 2:  30.0
# Quartil 3:  46.0
#
#
# Detail kolom Data 4
# rata-rata:  30.704
# Median:  32.0
# Modus:  ModeResult(mode=array([52]), count=array([15]))
# Standard deviasi:  17.773924271246347
# varian:  0.5788797639150061
# Skewness:  -0.03918001057467828
# Quartil 1:  16.0
# Quartil 2:  32.0
# Quartil 3:  46.0
